# %% [markdown]
# <a href="https://colab.research.google.com/github/shrav-jally/Amazon-Clone-w-HTML-CSS/blob/main/project_sem2_recap_).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**This notebook will be a recap of almost everything I've learnt in semester 2 of object oriented programming.** (~shravya)
#
# Unit 1: Introduction to object oriented programming paradigms//
#
# programming paradigms, advantages of oop, comparison of oop with procedural paradigms, classes and objects, prototyping, referencing variables in functions, inline static friend functions, memory allocation
#
# Unit 2: Polymorphism and Inheritance//
#
# overriding methods, type conversions, base classes and derived classes, inheritance types, classes types, invocation of constructors and destructors inheritance, aggregation, composition, classification hierarchies, meta abstract classes, unit testing and exceptions
#
# Unit 3: Python Libraries//
#
# basics of open source libraries for data-preprocessing, modeling and visualization
#
# Unit 4: Python to access Web Data//
#
# regular expressions, extracting data, sockets, using developer console to explore HTTP, retrieving and passing web pages
#
# Unit 5: Using databases with python//
#
# using databases, single table CRUD, designing and representing a data model, reconstructing data with JOIN, many-to-many relationships

# %% [markdown]
# #**questions**
# 1. differentiation between oop and procedural paradigms
# 2. outputs and errors in code related to theory
# 3. definition of numpy module and applications
# 4. explain instance, class, static methods with suitable code
# 5. explain memory allocation for classes and objects
# 6. explain different programming paradigms
# 7. code to create 2D array of ones of shape (3,4)
# 8. differentiate between aggregation and composiiton with suitable program
# 9. explain types of inheritance with suitable programs
# 10. define and demonstrate unit testing w suitable program using unittst module and its methods
# 11. define abstrace class 'Shape' w abstract methods getData(), and printArea(), which should be implemented in derived classes 'circle', 'square' and 'rectangle' to calculate their area and display
# 12. define class 'Employee' with member variables: Empid, Empname, Dept and member functions" getDateofJoin() with member variables dd,mm,yy and member function Service() which should calculae employee service in number of days from the joining date displayDetails() should display employee name and service as output
# 13. create 2d arrays with shape (3, 4)
# 14. list any 4 commonly used database systems
# 15. write python program to retrieve phone number with format 123-456-7890
# from given input string
# 16. illustrate array sorting functions of numpy with examples
# 17. write pandas program to demonstrate handling of missing data in a dataframe
# 18. illustrate re.match(), re.search()
# 19. differentiate greedy and non-greedy matches using example indicating corresponding regular expressions
# 20. explain steps involved in designing and representing data model
# 21. explain different types of join ops used to reconstruct data
# 22. py prog performing CRUD ops using SQLite3 on the 'employees' table: emp_id(integer, primary key), name(text), position(text): create 'employees' table with specified schema, insert 2 rows of data into the frame, update the position of an employee w a specific id
#
#
# here go some 3m sem questions
#
#
# 1. write a python program to circuate the values of n variables
# 2. what're different ways to pass arguments in python
# 3. compare constructors and destructors, give example of overloaded constructor
# 6. uses of friend functions
# 7. define abstract classes
# 8. how to install a package in python
# 9. list uses of socket
# 10. define database and list applications
# 11. what're membership operators, examples of uses
# 12. try-except block sytax
# 13. define abstract class, why can't we create an object for it
# 14. give short note on built-in functions used with objects
# 15. difference between error and exception
# 16. explain classes and objects in python using examples
# 17. switch statement
#
#
# here go some 5m sem questions
#
# 1. Compare and contrast the structured programming and object oriented
# programming techniques.
# 2. Explain with example When do we overload the functions and when
# do we override.
# 3. Evaluate a try block that is likely to generate three types of exception
# and then incorporate necessary catch blocks and handle them
# appropriately.
# 4. What is exception handling? Explain types of exception handling with
# suitable example.
# 5. While reading a file how would you check whether you have reached
# the end of the file? Explain with example program.
# 6. With an example, explain how member functions can be overridden.
# What is the scope resolution of these functions?
# 7. Demonstrate Multiple Inheritance through Method Overriding with an
# example written in python.
# 8. Build a program to demonstrate overloading of ‘+’ operator inside a
# class student that has attributes name and marks.
# 9. Define nested class. List out its advantages. Support your answer with
# proper examples.
# 10. Create a class called Time that has separate int member data for hours,
# minutes and seconds. One constructor should initialize this data to 0.
# And another should initialize it to fixed values. A member function
# should display it, in 11:59:59 format. Write a program to add time of
# two objects by overloading '+' operator.
# 11. Why does the object-oriented philosophy need functions to be defined
# inside the classes? What could be the advantage?
# 12. Define a class. What is the relation between an object and a class?
# Write a program to define a class, to access its member functions and
# to create and access objects in Python.
# 13. Distinguish call by value and call by reference, supported with
# example.
# 14. Write a Python program to count the number of vowels in a string
# provided by the user.
# 15. Compare the OOP with Procedural Paradigms and list the merits and
# demerits.
# 16. How and when the memory is allocated for a constructor? Show with an
# example.
# 17. List the OOP features and write the advantages.
# 18. Discuss the inline and static functions with an example.
# 19. What are advantages of OOPs polymorphism?
# 20. Differentiate compile time and run time polymorphism.
# 21. Discuss the JOIN operation in detail with suitable example.
# 22. Write a program to access the employee table that contains the name, Id,
# department, Salary. Also display second highest salary drawn employee
# details.
# 23. Write the syntax’s of CRUD operations.
# 24. Write a program to access the employee table that contains the name, Id,
# department, Salary. Also find the average salary of employees who are
# working in a specific department.
# 25. How the socket and HTTP are used in communication. Explain with an
# example.
# 26. Write a program to extract and process the data stored in a file.
# 27. Write a program that finds the sum of the numbers in the given file that
# contain numeric data
# 28. Write a program that counts the matched string in a given webpage.
# 29. Write a program that finds the sum of the numbers in the given file that
# contain numeric data.
# 30. Explain various functions used for data modelling in Python.
# 31. Discuss with examples of various functions used for data preprocessing.
# 32. Write a program to find the union of two arrays. Union will return a
# unique, sorted array of values in each of the two input arrays.
# 33. Discuss with examples of various functions supported by NumPy and
# Pandas.
# 34. What is inheritance? Explain different types of inheritance with
# examples.
# 35. Write a Program to create an abstract class named Shape that contains
# two integers and an empty method named print Area ().provide three
# classes named Rectangle, Triangle and Circle such that each one of the
# classes extends the class Shape. Each one of the classes contains only the
# method print Area () that prints the area of the given shape.

# %%
nterms=int(input("enter number of values:"))
list1=[1,2,3,4,5]
for var in range (0,nterms,1):
    t=int(input("enter integer:"))
    list1.append(t)
print("circulating the elements oflist",list1)
for var in range(0,nterms,1 ):
    t=list1.pop(0)
    list1.append(t)
    print(list1)

# %%
#unit 1
'''there's no point of having classes unless you're doing data encapsulation'''
'''__init__ constructor runs as soon as an object is instantiated from that class'''
'''
generations of programming languages (5)
low(machine level,  assembly level), high(C, python, prolog/mercury) 1,2,3-procedural oriented 4,5-non-procedural oriented

programming paradigms- monolithic, subroutine/ functional/ procedural, structured/ modular, object oriented/ data centric (access specifiers),
rule based, constriant based, logic oriented

oops concepts:- class  object  data abstraction  data encapsulation  inheritance  polymorphism  containership  delegation  message passing
'''
'''
class- user defined data type consisting of data and methods, object- instance of class (accessing, assigning) , docstrings :)
class:object::function:call
class components- data(attributes/class variable, members/object variables/instance variables), methods(public, private, special(constructors),
static, class, inline, friend)

class var and object var differences,
built-in functions( to know object properties),
hasattr(objname, 'varname'), getattr(objname, 'varname'), setattr(objname, 'varname', value), delattr(objname, 'varname')
built-in class attributes,
.__name__, .__bases__}class name, .__dict__, .__doc__, .__module__}object name


data is public, _protected, __private knowing usage and methods of these data types in crucial in py oops

public data-public method
class emp:
  id=0          #public data(any object can access it)
  def display(self, i):
    self.sal=i                             #self here used to refer to the object calling it in class method,
    print("this is a method", self.sal)        #more parameters(in class definition), or arguments(in object instantiation) can be given (i)
e1=emp() #instantiating a random object            #you can also create a variable within a class method too (self.sal)
print(e1.id) #random object accessing public data
e1.display(5) #random object accessing public method

eppudaina object ni instantiate chesi inka nachinattu vaduko :)
when you write an attribute of an object that dne, py sys won't complain but just create a new one
# objectname.kothaattributename= something

private data( called by public/private methods, friend method (3 ways))-
private method( called by public methods, meant to call private data, call public data) (__- the 2 underscores rule private part of oop)

non-member and member(have self argument) functions difference
when nmf calls mf, nmf sh have object as it's parameter and nmf can call nmf
def dis(obj):
  print("cbit")
  obj.m1()
class A:
  def m1(self):
    print("hi")
obj=A()
dis(obj)     #prints cbit and hi

you can alter fixed variables'(a=10) values in runtime:-   a1=A(), a1.a=20

special methods( initializes an object when it's not even created)(constructors are used to construct an object using arguments wrt class like self)
constructor- def __init__(self, other parameters):   constructors types- parameterized, non-parameterized, default
destructor- def __del__(self):
__repr__ (while calling 'repr()', 'objname.__repr__()', 'repr(objname)'),
__len__ (calling same as above), __cmp__ (a1.__cmp__(a2), basically true/false comparison control statement)

class and instance variables. . .difference, if we change class variable value for one object during runtime, it changes for all objects

instance methods
class shape:
    def __init__(self, edge, color):
        self.edge = edge
        self.color = color
    def finEdges(self):            #instance method
        return self.edge
    def modifyEdges(self, newedge):     #instance method
        self.edge = newedge
circle = shape(0, 'red')
square = shape(4, 'blue')
print("No. of edges for circle: "+ str(circle.finEdges()))    #calling instance method, and the below 2 also that only lol
square.modifyEdges(6)
print("No. of edges for square: "+ str(square.finEdges()))

class methods, normal mf(self, ...), cf(cls, ...), access class variables preferably
@-decorator-adds functionality to a method to behave a certain way   (meta-programming method)
snippet of code using decorator
class stu:
  collegename='cbit'
  @classmethod
  def m1(cls):
    print(cls.collegename)
stu.m1() #>>cbit

static methods, process class data, @staticmethod, no parameters like cls/self, called using class/object name, actually "independent" of class
class Maths():
  @staticmethod
    def addNum(num1, num2):
        return num1 + num2
res = Maths.addNum(1, 2)    #calling class method without creating an instance
print("The result is", res)

inline method( lambda function, can't access global data, python doesn't support)

friend method( python doesn't support, @property)
class A:
  def.__init__(self, i):
    self.__var=i
    @property
    def display(self):
      return self.__var
a1=A(10)
print(a1.display) #no brackets for display here cause we're accessing private data lmao, to call method not as method but attribute
'''
'''
memory allocation (copy by value and copy by reference has application here)
import sys
class A:
  def __init__(self, id, name):
    self.i=id
    self.j=name
a1=A(63,'shrav')
objsize=sys.getsize(a1)
classsize=sys.getsize(A)

reference counting
arrays of objects

applications and advantages of oops
types of arguments are positional, keyword and default
'''

# %%
#unit 2
'''
inheritance: single, multiple, multilevel, hybrid, multiple path, hierarchial (existing/parent, to, derived/new/child)
isinstance(object, class), issubclass(to check subclass, of superclass)
polymorphism: compile time( method overloading, operator overloading), runtime( method overriding)
--which method is being called depends on object that's calling
inheritance(related to classes, is-a relationship)     polymorphism(related to methods, overriding or overloading)
c.__mro__ ( attribute), c.mro() ( method)

depth first rule >> associativity rule

super function,  containership aka composition (chain of function call), abstract classes
class Fruit(ABC):
  @Abstractmethod
  def taste(self):
    pass

relating real world objects to code is done through :
inheritance, composition (dependent), aggregation(independent)

exceptions and exception handling
try except else finally

# %%
#unit 3
'''
numpy-numeric python (efficient implementation of arrays bro) (matrices, n-dimensional arrays)
the complete machine learning ecosystem includes- numpy, matplotlib,  pandas, scikitlearn, tensorflow
number of dimensions- axes, number of axes- rank
import numpy as np
np.array(list/tuple)
np.zeroes((n, m))     #n=vertical, m=horizontal
np.ones((n, m), dtype= np.int16)
np.full((n, m), value)
np.arange(start, stop, skip)    #it accepts float arguments
np.linspace(start, stop, no. of points)
np.random.rand(n, m)
np.empty((n, m))
ndarray.ndim, ndarray.shape, ndarray.size, ndarray.dtype, ndarray.itemsize
a.reshape(2, 3)   #for 6 elements
accessing, ranging, and slicing 1D arrays based on indexing
a[1:3] = -1   #you can assign a const. over a slice for 'np.array([])', but not for '[]'
modifying slice will modify original array as well (slices are just modified views of the same data set)
a[2:6].copy()   #this will create another individually modifiable, modified data set (a copy)
Array[row_start_index:row_end_index, column_start_index:column_end_index]   #indexing multidimensional arrays
b[1, 2] #row 1 col 2,  b[1, :] #row 1 all columns,  b[:, 1] #all rows column 1      #accessing multidimensional arrays

linear algebra with numpy

representing a vector numpy.array([1,1,1,1])
'''
"""
pandas and matplotlib refer the practice notebook
"""

# %%
#unit 4
"""
web scraping aka web data extraction (unstructured data -> structured)      remember applications     /robots.txt
process of scrapig data from a website (beautiful soup(pip install bs4, to pull data from HTML, XML files), re module)
HTML- specifies set of tags <>, used to identify structure and content type of webpage
boilercode (basic layout/ foundation)
important tags (<head>, <body>, <h1>, <d>, <p>, <div>, <span>, <ol>, <ul>, <li>, <table>, <th>, <tr>)
html-hypertext markup language http-hypertext transfer protocol
in web scraping there is no rendering, just parsing
parsers like html5lib, lxml can create nested tree structure of html data, beautiful soup is the py lib that can navigate this tree and pull data
soup = BeautifulSoup("doc.html", "html.parser")   #doc.html is the opened file
soup.head.title     #go in the order of outermost to innermost to parse what you want (mention all tags along the path)
soup.find_all("enter tag for which you want to find matches")
soup.find_all("tag", class_="element to which search of tags narrows")

-------------------------------------------------------------------------------------------------------------------------------------------------
regex/regexp- pattern matching, string searching, data validation, text manipulation
import re
^, $, ., \s, \S, *, *?, +, +?, [aeiou], [^XYZ],
[a-z0-9], (, ), d, \D, \w, \W, ?, {n}, {n,}, {n, m}
[], [^], (pattern), (?:pattern), \b, \B, [0-9]+, ^F.+:, ^F.+?:
| (either or), \ (signals special sequence (can also used to escape special characters))
\A, \Z, [0-5][0-9], [+]

re.search() (we can print a search value and call it match object, not print it and call it search()), re.findall(), re.match() -pattern, string
.split(pattern, string, maxsplit=0), .sub(pattern, repl, string, maxsplit=0)
x.start()
match object- (syntax- <re.Match object; span=(5, 7), match='ai'>), .span(), .string, .group()
re.compile(pattern) - compiles regular expression into pattern object (email_pattern.findall/search/match(text))
re.group(n) - returns nth captured group from the match

for i, match in enumerate(matches, start=1):
print(f"Email {i}: {match}")

matched_urls = [url for url in urls if pattern.match(url)]
for url in matched_urls:
 print("Matched URL:", url)

greedy( default) and non-greedy quantifiers

sockets( API( client-server))(combo of IP address and port)( TCP built on IP)(1 network, 2 sockets)
terms- domain( the family of protocols that's used as transport mech), type( connection-oriented/connectionless protocols),
protocol, ports( virtual endpoints for communication in network)(0-65535), hostname( identifier of a network interface)

import socket
s = socket.socket (socket_family, socket_type, protocol=0)    #(AF_UNIX or AF_INET), (SOCK_STREAM or SOCK_DGRAM), protocol usually left out

socket module: socket.socket(), socket.accept() (output(conn, address)), socket.bind(), socket.close(), socket.connect(), socket.listen()

server and client communication
name a file : sockets_server.py , and code
import socket
myserver=socket.socket(socket.AF_INET,socket.SOCK_STREAM)
myserver.bind((socket.gethostname(), 1024))
myserver.listen(5)
while True:
  myclient,addr=myserver.accept()
  print(f"Connection to {addr} established")
  myclient.send(bytes("Welcome to Socket Programming in Python!", "utf-8"))

name a file : sockets_client.py , and code
import socket
myserver=socket.socket(socket.AF_INET,socket.SOCK_STREAM)
myserver.connect((socket.gethostname(), 1024))
msg=myserver.recv(1024)
print(msg.decode("utf-8"))

establishing connection:
open 2 command prompt windows
change directories to where above files are located
run server program "py sockets_server.py" in one and client program in the other "py sockets_client.py" chronologically
server window shows connection is established

Using the Developer Console to Explore HTTP and Retrieving Web Page
HTTP( application layer protocol for web) (make connection, request doc, retrieve doc, close connection)
http://www.dr-chuck.com/page1.htm - protocol/host/document pattern (actually opens upto html page)
(illustrates getting data from server through GET (requesting data from server))
(there's also POST (submitting data to server))
httplib, urllib, requests- libraries to make requests in http

# %%
#unit 5
'''
storing data in program(temporary) file(inefficient, complex) database(flexible, simple)
dbms-collection of interrelated data (SQL(non-procedural) is the DBMS language)
     to avoid data redundancy and inconsistency
     to avoid difficulty in accessing data
     to deal with data isolation
     to deal with integrity problems
     atomic updates
     concurrent access by multiple users
     security

(language of dbms) sql-data definition language, data manipulation language
-select<attributes>/*-from<one or more relations>-where<conditions>-   (and/ or can be used to combine conditions)(or replacable w IN)

table name, attributes (headers), tuple (header+values, like column), row (list of values under all headers)

schema- table name(attributes data types constriants)
data types-( numeric, character-string, boolean, date, timestamp)
constriants-restrictions on values of attributes
(attribute-domain constriants: UNIQUE, CHECK, DEFAULT, NOT NULL)
(key constriants: PRIMARY KEY( not null+unique))
(Key and referential integrity constraints)

creating a database:(CREATE DATABASE  <DATABSE NAME>;, USE  <DATABSE NAME>;, show tables;)
CREATE TABLE <TABLE NAME> (<ATTR1> <DATA TYPE> <CONSTRAINT>, <ATTR2> <DATA TYPE> <CONSTRAINT>);
Desc <tablename>;  (describes structure of existing table)

# we use the schema to make the top header row, then use
insert into <table name>(optionally specify heading name(s)) values("x", y, "z");

PYTHON MYSQL(open source relational SQL dbms) connectivity:
steps to connect- import mysql.connector module, create the connection object, create the cursor object, execute the query
arguments required- username, password, hostname, database name

import mysql.connector
conn= mysql.connector.connect(host = <hostname>, user = <username>, passwd = <password>)
print(conn)   #connection object controls the connection to database
cur= conn.cursor()    #we need cursor to execute MySQL queries          #THIS PART COMMON

cur.execute("create database telephoneDir")   #we can create databases
cur.execute("show databases")   #using cursor object to run any MySQL query using .execute()

for x in cur:   #fetching databases from cur 1 by 1                     #THIS PART COMMON
  print(x)
conn.close()

creating a table using execute():
cur.execute("use telephoneDir")
cur.execute("create table customer( cust_id int(5), cust_name varchar(40), tele_no varchar(15), reg_date date)")
cur.execute("show tables")

give database="telephoneDir" in connection object and cur.execute("desc customer") to view table structure

inserting data into table customer using execute():
cur.execute("use telephoneDir")
cur.execute('insert into customer values("an id", "a name", a number, "a date")')
cur.execute("select * from customer")

inserting records by taking input by user: give database="telephoneDir" in connection object and
id=int(input())
nam=input()
num=input()
dt=input()
qry='insert into customer values(%s, %s, %s, %s)'   #format specifier
val=(id, nam, num, dt)
cur.execute(qry, val)
conn.commit()
cur.execute("select * from customer")
xs
.executemany(), to insert multiple records at once:
qry='insert into customer values(%s, %s, %s, %s)'
val=[(a, b, c, d), (e, f, g, h)]
cur.executemany(qry, val)
conn.commit()
cur.execute("select * from customer")

upgrading code: give database="telephoneDir" in connection object and
id=int(input("id of customer to be identified: "))
nam=input("new name")
qry=("update customer set cust_name=%s where cust_id=%s")
val=(nam, id)
cur.execute(qry, val)
conn.commit()
cur.execute("select * from customer")

deleting records: give database="telephoneDir" in connection object and
id=int(input("id of customer to be deleted: "))
qry=("delete from customer where cust_id=%s")
val=(id,)
cur.execute(qry, val)
conn.commit()
cur.execute("select * from customer")

print(cur.rowcount)   #after executing any query
conn.commit()
conn.close()

cur.fetchall(), cur.fetchmany(size), cursor.fetchone()

Error Handling:
import mysql.connector
from mysql.connector import Error
from mysql.connector import errorcode
def display():
  try:
    conn= mysql.connector.connect(host = <hostname>, user = <username>, passwd = <password>, database="telephone") #database DNE
    cur= conn.cursor()
    cur.execute("select * from customer")
    for (cust_id, cust_date, tele_no, reg_date) in cur:
      print(cust_id, cust_date, tele_no, reg_date)
    cur.close()
    conn.close()
    print("ya did it")
  except mysql.connector.Error as err:
    if err.errno == errorcode.ER_ACCESS_DENIED_ERROR:
      print("Something is wrong with your user name or password")
    elif err.errno == errorcode.ER_BAD_DB_ERROR:
      print("Database does not exist")
    else:
      print(err)
  else:
    conn.close()
display()
>>>Database does not exist

colab commands: connect(.db), cursor(), execute(), executemany(), fetchall(), commit(), close() (close connection and cursor after work done), etc.
python to SQLite: None(NULL), str(TEXT), int(INTEGER), float(REAL), bytes(BLOB)
CRUD- sqlite create, read, update, delete

idky but we usually include try, except and finally blocks while writing sqlite codes
import statements
any function definitions
try:
  all the functioning code( conn, cur, execute crud, commit, close)
except sqlite3.Error as error:
    print("failed to do whatever's in try", error)
finally:
    if conn:          #another way to say that if the connection is successfully established
        conn.close()

selecting rows from SQLite table.

DESIGNING AND REPRESENTING DATA MODELS(blueprint for designing data models)
common model is ER(entity-relationship) model, 8 steps:
identify entities  define their attributes  establish relationships  determine cardinality  model constriants   design primary & foreign keys
represent the data model(ERD)  validate and refine

ERD
rectangle, ellipse, diamond, line, double-ellipse, double-rectangle, dotted ellipse, primary key

entity, weak entity, key/ composite/ multivalued/ derived attributes, 1-1/ 1-many/ many-many/ many-1 relationships

reconstructing data with join: identify the tables  understand the relationship  choose the join type(inner/ left/ right/ full)
specify the join condition
'''
# Out:
# '\nstoring data in program(temporary) file(inefficient, complex) database(flexible, simple)\ndbms-collection of interrelated data (SQL(non-procedural) is the DBMS language)\n     to avoid data redundancy and inconsistency\n     to avoid difficulty in accessing data\n     to deal with data isolation\n     to deal with integrity problems\n     atomic updates\n     concurrent access by multiple users\n     security\n\n(language of dbms) sql-data definition language, data manipulation language\n-select<attributes>/*-from<one or more relations>-where<conditions>-   (and/ or can be used to combine conditions)(or replacable w IN)\n\ntable name, attributes (headers), tuple (header+values, like column), row (list of values under all headers)\n\nschema- table name(attributes data types constriants)\ndata types( numeric, character-string, boolean, date, timestamp)\nconstriants-restrictions on values of attributes\n(attribute-domain constriants: UNIQUE, CHECK, DEFAULT, NOT NULL)\n(key constriant
# ...
